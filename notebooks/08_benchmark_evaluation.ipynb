# %% [markdown]
# # Notebook 08: Benchmark Evaluation

# %%
# This notebook demonstrates evaluation once benchmark datasets are available.
# Results are NOT fabricated — 'NOT RUN' is returned when data is unavailable.

import os
from src.evaluation.metrics import vqa_accuracy, change_f1, caption_scores

print('Evaluation metrics available:')
print('  VQA: vqa_accuracy, vqa_accuracy_by_type')
print('  Captioning: BLEU-4, ROUGE-L (from scratch, no nltk download)')
print('  Grounding: IoU, accuracy@0.5')
print('  Change: pixel F1, precision, recall, IoU, Cohen kappa')
print('  Fusion: macro/micro F1, per-class F1, exact match accuracy')

print()
print('To run evaluation on downloaded benchmarks:')
print('  python scripts/evaluate.py --task vqa --dataset rsvqa --write-results')
print('  python scripts/evaluate.py --task change --dataset cdvqa --write-results')
print('  python -m src.evaluation.generate_report')
