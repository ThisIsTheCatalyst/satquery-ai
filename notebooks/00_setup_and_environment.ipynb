# %% [markdown]
# # Notebook 00: Setup and Environment
#
# Install dependencies and verify the SatQuery AI environment.

# %%
# !git clone <repo-url> satquery-ai
# %cd satquery-ai
# !pip install -r requirements-colab.txt -q

# %%
# !python scripts/check_environment.py

# %%
# !python scripts/smoke_test.py --no-load
